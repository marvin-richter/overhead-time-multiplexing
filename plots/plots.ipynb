# %% [markdown]
# # Plots from Publication
# Please note: minor changes to the figures in the publication are caused by different seeds.
#
# The config that can be used to create the data shown in the plots is also noted. Some data generation can take hours.

# %% [markdown]
# # Fig 2 (left column) - Random circuits on 5x5 grid

# %% [markdown]
# Data was generated from config: `configs/paper/fig2_5x5.yaml`

# %%
import plot_fig02_fig17

fig = plot_fig02_fig17.plot_figure("5x5")

# %% [markdown]
# # Fig 2 (right column) - Random circuits on 11x11 grid

# %% [markdown]
# Data from config `configs/paper/fig2_11x11.yaml`

# %%
import plot_fig02_fig17

fig = plot_fig02_fig17.plot_figure("11x11")

# %% [markdown]
# # Fig 3 - Scaling analysis of random circuits for different sized grids

# %% [markdown]
# Data can be generated from `configs/paper/fig3_random_grids.yaml`.

# %%
import plot_fig03

fig = plot_fig03.plot_figure()
# Out:
# Routing overhead: a=2.17e-06±9.64e-08, b=1.289±0.008
# Serial k=8: a=2.26e-06±4.78e-07, b=1.478±0.035
# Serial k=4: a=1.50e-06±3.66e-07, b=1.457±0.038
# Serial k=2: a=9.02e-07±4.28e-07, b=1.382±0.070
# Target circuits: a=2.06e-05, b=0.040

# %% [markdown]
# # Fig 4 - MQT Bench Circuits on 11x11 grid

# %% [markdown]
# Data generated via `configs/paper/fig4_mqt_11x11.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("line_11x11")
# Out:
# hardware: 11x11

# %% [markdown]
# # Fig 5 - Histogram: MQT Bench Circuits on 11x11 grid

# %% [markdown]
# Data generated via `configs/paper/fig4_mqt_11x11.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("hist_11x11")
# Out:
# hardware: 11x11
# total counts: 3240

# %% [markdown]
# # Fig 6 - Scaling of QFT for grid devices

# %% [markdown]
# Data can be generated from `configs/paper/fig6_qft_grids.yaml`.

# %%
import plot_fig06

fig = plot_fig06.plot_figure()
# Out:
# Routing overhead: a=2.93e-06±3.68e-08, b=1.023±0.002
# Serial k=8: a=2.93e-06±7.48e-07, b=1.076±0.039
# Serial k=4: a=2.75e-06±1.02e-06, b=1.023±0.058
# Serial k=2: a=1.15e-06±2.36e-07, b=1.041±0.034
# QFT (native): a=8.31e-07±2.79e-09, b=1.005±0.001
# Target circuits: a=8.31e-07, b=1.005

# %% [markdown]
# # Fig 7 - Prediction of serialization overhead of random gates for 11x11 grid

# %% [markdown]
# Data can be generated from `configs/paper/fig7_random_11x11_scaling.yaml`.

# %%
import plot_fig07

fig = plot_fig07.plot_figure()

# %% [markdown]
# # Fig 8 - MQT Fit (11x11 grid)

# %% [markdown]
# Data can be generated from `configs/paper/fig8_mqt_11x11_scaling.yaml`.

# %%
import plot_fig08_fig24

fig = plot_fig08_fig24.plot_figure("fig08")
# Out:
# Circuit shor: p = 6.4e-01 ± 1.0e-02
# Circuit qaoa: p = 1.3e+00 ± 1.5e-02
# Circuit qpeexact: p = 9.2e-01 ± 9.8e-03
# Circuit vqe_su2: p = 5.8e-01 ± 8.6e-03
# Circuit bmw_quark_cardinality: p = 8.0e-02 ± 2.7e-03
#
# Fitted Parameters Summary:
# Circuit ID | A (fitted) | Fit Error
# -------------------------------------------------------
# shor      | 6.427e-01 | 1.047e-02
# qaoa      | 1.308e+00 | 1.497e-02
# qpeexact  | 9.202e-01 | 9.843e-03
# vqe_su2   | 5.775e-01 | 8.598e-03
# bmw_quark_cardinality | 7.972e-02 | 2.708e-03

# %% [markdown]
# # Fig 9 - Different ratios of single-qubit gate times to two-qubit gate times

# %% [markdown]
# Data can be generated using `configs/paper/fig9_mqt_t1t2.yaml`

# %%
import plot_fig09

fig = plot_fig09.plot_figure()

# %% [markdown]
# # Fig 10 - Different Switch Times

# %% [markdown]
# Data can be generated using `configs/paper/fig10_mqt_tsw.yaml`

# %%
import plot_fig10

fig = plot_fig10.plot_figure()

# %% [markdown]
# # Fig 11 - Comparison of optimization methods

# %% [markdown]
# Data can be generated with `configs/paper/fig11_optim_11x11.yaml`

# %%
import plot_fig11

fig = plot_fig11.plot_figure()

# %% [markdown]
# # Fig 13 - Comparison of different layouts for selected circuits

# %% [markdown]
# Data generated from `configs/paper/fig13_mqt_layouts.yaml`

# %%
import plot_fig13

fig = plot_fig13.plot_figure()

# %% [markdown]
# # Fig 14 - MQT Bench circuits on a 5x5 grid device

# %% [markdown]
# Data generated from `configs/paper/fig14_mqt_5x5.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("line_5x5")
# Out:
# hardware: 5x5

# %% [markdown]
# # Fig 15 - Detail plot of MQT Bench circuits on a 5x5 and 11x11 grid device

# %% [markdown]
# Data generated from `configs/paper/fig14_mqt_5x5.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_detail_grid()

# %% [markdown]
# # Fig 16 - Histogram of overheads for a 5x5 grid device and random circuits

# %% [markdown]
# Data generated from `configs/paper/fig14_mqt_5x5.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("hist_5x5")
# Out:
# hardware: 5x5
# total counts: 3780

# %% [markdown]
# # Fig 17 - Overheads of random circuits for 127qb IBM "eagle" device `ibm_brisbane`

# %% [markdown]
# Data generated from `configs/paper/fig17_random_brisbane.yaml`.

# %%
import plot_fig02_fig17

fig = plot_fig02_fig17.plot_figure("brisbane")

# %% [markdown]
# # Fig 18 - Overheads of MQT Bench circuits for 127qb IBM "eagle" device `ibm_brisbane`

# %% [markdown]
# Data generated from `configs/paper/fig18_mqt_brisbane.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("line_brisbane")
# Out:
# hardware: brisbane

# %% [markdown]
# # Fig 19 - Detail plot of MQT Bench circuits on `ibm_brisbane`

# %% [markdown]
# Data generated from `configs/paper/fig18_mqt_brisbane.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_detail_brisbane()

# %% [markdown]
# # Fig 20 - Histograms for 127qb IBM device (Eagle generation/ `ibm_brisbane`)

# %% [markdown]
# Data generated from `configs/paper/fig18_mqt_brisbane.yaml`

# %%
import plot_mqt_figures as plot_mqt_figures

fig = plot_mqt_figures.plot_figure("hist_brisbane")
# Out:
# hardware: brisbane
# total counts: 3240

# %% [markdown]
# # Fig 23 - Theoretical model

# %% [markdown]
# Data is generated in the plotting code.

# %%
import plot_fig23

fig = plot_fig23.plot_figure()
# Out:
# ...
# 100%|██████████| 12/12 [00:10<00:00,  1.17it/s]

# %% [markdown]
# # Fig 24 - Complete fits for 11x11 grid and MQT Bench circuits

# %% [markdown]
# Data can be generated from `configs/paper/fig8_mqt_11x11_scaling.yaml`.

# %%
import plot_fig08_fig24

fig = plot_fig08_fig24.plot_figure("fig24")
